# %% [markdown]
# <a href="https://colab.research.google.com/github/Irfan-programer/Dasar-program/blob/main/Pertemuan_2_Malam_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Latihan 1

tegangan = 18        # int
ampere = 6           # float
jenis_sel = "monocrystalline"  # str

print(tegangan, ampere,jenis_sel,)
# Out:
# 18 6 monocrystalline

# %%
# Latihan 2
Hambatan = 0,7
Arus = 7
Label = "resistor"
ohm = True


print(type(Hambatan))
print(type(Arus))
print(type(Label))
print(type(ohm))
# Out:
# <class 'tuple'>
# <class 'int'>
# <class 'str'>
# <class 'bool'>

# %%
# Latihan 3
nama_unit = "PLTS Nunukan"
jumlah_panel = 240
tegangan_keluaran = 48.5
sedang_beroperasi = True

print(nama_unit,type(nama_unit))
print(jumlah_panel,type(jumlah_panel))
print(tegangan_keluaran,type(tegangan_keluaran))
print(sedang_beroperasi,type(sedang_beroperasi))
# Out:
# PLTS Nunukan <class 'str'>
# 240 <class 'int'>
# 48.5 <class 'float'>
# True <class 'bool'>

# %%
# Latihan 4
# pembacaan pertama dan terakhir memakai indeks
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]
print(tegangan_harian[0], tegangan_harian[5])

# tambahkan satu pembacaan baru 220.0 dengan append()
tegangan_harian.append(220.0)
print(tegangan_harian)

# cetak jumlah total data dengan len()
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9, 222.0]
print(len(tegangan_harian))
# Out:
# 217.5 216.9
# [217.5, 219.0, 220.3, 218.7, 221.1, 216.9, 220.0]
# 7

# %%
# Latiham 5
motor = {
    "nama": "motor_listrik",
    "daya_kW": 380,
    "tegangan_V": 22,
    "rpm" : 1800
}
print("daya:", motor["daya_kW"], "kW")

# ubah nilai rpm pakai =
motor["rpm"] = 1650

print(motor)
# Out:
# daya: 380 kW
# {'nama': 'motor_listrik', 'daya_kW': 380, 'tegangan_V': 22, 'rpm': 1650}

# %%
# Latihan 6
pembangkit = [
    {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"nama": "Unit-3", "kapasitas_MW": 80,  "status": "pemeliharaan"},
]
print(pembangkit[1])

# ubah status salah satu unit
pembangkit[1]["status"] = "pemeliharaan"
print(pembangkit[1])

# tambahkan 1 unit baru dengan append()
pembangkit.append({"nama": "Unit-4", "kapasitas_MW" : 135, "status": "operasi"})
print(pembangkit)
# Out:
# {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}
# {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'pemeliharaan'}
# [{'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'operasi'}, {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'pemeliharaan'}, {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'pemeliharaan'}, {'nama': 'Unit-4', 'kapasitas_MW': 135, 'status': 'operasi'}]
