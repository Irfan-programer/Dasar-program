# %% [markdown]
# <a href="https://colab.research.google.com/github/Irfan-programer/Dasar-program/blob/main/pertemuan_1_malam_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# biodata saya

nama = "irfan"
umur = 20
jurusan = "RPE"
semester = 3
matakuliah = 'pemerograman dasar'
status_lulus = False


print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# irfan
# 20
# RPE
# 3
# pemerograman dasar
# False
